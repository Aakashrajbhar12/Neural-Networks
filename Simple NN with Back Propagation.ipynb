# %% [markdown]
# ### Simple Neural Network With Back Propagation

# %%
#Library Required to Install Before Running this Code First Time
#!pip install tensorflow
#!pip install keras

# %%
#Importing the Required Library
# Create your first MLP in Keras
from keras.models import Sequential
from keras.layers import Dense
import numpy as np
import pandas as pd

# %%
# fix random seed for reproducibility
seed = 7
np.random.seed(seed)
#Loading the Dataset
#dataset = np.loadtxt("pima-indians-diabetes.csv", delimiter=",")
Dataset = pd.read_csv("C:/Users/Akaash/Downloads/pima-indians-diabetes.csv", header = None)
# split into input (X) and output (Y) variables
X = Dataset.iloc[:,0:8]
Y = Dataset.iloc[:,8]

# %%
# create model
model = Sequential()
#When you get initializer Error pass this below parameter
#kernel_initializer = 'uniform'
model.add(Dense(12, input_dim=8, activation='relu')) #1st Layer
model.add(Dense(8, activation='relu')) #2nd Layer
model.add(Dense(1, activation='sigmoid')) #3rd layer

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Compile model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Fit the model
model_history = model.fit(X, Y, validation_split=0.33, epochs=500, batch_size=10)
# Out:
# Epoch 1/500
# 52/52 [==============================] - 4s 25ms/step - loss: 14.2475 - accuracy: 0.4767 - val_loss: 9.1641 - val_accuracy: 0.4961
# Epoch 2/500
# 52/52 [==============================] - 1s 11ms/step - loss: 7.2626 - accuracy: 0.4533 - val_loss: 3.8147 - val_accuracy: 0.4764
# Epoch 3/500
# 52/52 [==============================] - 1s 11ms/step - loss: 2.9177 - accuracy: 0.3891 - val_loss: 1.7004 - val_accuracy: 0.3543
# Epoch 4/500
# 52/52 [==============================] - 1s 11ms/step - loss: 1.5955 - accuracy: 0.4066 - val_loss: 1.2694 - val_accuracy: 0.4567
# Epoch 5/500
# 52/52 [==============================] - 1s 11ms/step - loss: 1.2131 - accuracy: 0.4942 - val_loss: 1.1578 - val_accuracy: 0.5000
# Epoch 6/500
# 52/52 [==============================] - 1s 11ms/step - loss: 1.0597 - accuracy: 0.5350 - val_loss: 0.9911 - val_accuracy: 0.5709
# Epoch 7/500
# ...

# %%
# evaluate the model
scores = model.evaluate(X, Y)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# 24/24 [==============================] - 1s 10ms/step - loss: 0.4575 - accuracy: 0.7904
# accuracy: 79.04%

# %%
# Visualize training history

# list all data in history
model_history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
import matplotlib.pyplot as plt
# summarize history for accuracy
plt.plot(model_history.history['accuracy'])
plt.plot(model_history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
